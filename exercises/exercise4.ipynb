# %% [markdown]
# Implimentation plan:
#     Set variables for the # of lines, words, characters, and the dictionary
#     Loop through every line of the file and increment the count by 1
#     Split every line of the file into words, adding the line's length in words to the word count
#     Go through each line (a list now) and if a word is in the dictionary, increment it's count; if it's not, add it to the dictionary
#     Get the length of each word and add it to the character count
#     Check how lines/words look as I go, alter code to make it look cleaner

# %%
file=open('R_J.txt','r')
for i in range(0,15): #takin a look at the first few lines
    line=file.next()
    print line
# Out:
# Project Gutenberg Etext of Romeo and Juliet by Shakespeare
#
# PG has multiple editions of William Shakespeare's Complete Works
#
#
#
#
#
# Copyright laws are changing all over the world, be sure to check
#
# the copyright laws for your country before posting these files!!
#
#
#
# Please take a look at the important information in this header.
#
# We encourage you to keep this file on your own disk, keeping an
#
# electronic path open for the next readers.  Do not remove this.
#
#
#
#
#
# **Welcome To The World of Free Plain Vanilla Electronic Texts**

# %%
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in range(0,15): #taking a look at the first few split lines
    line=file.next().split()
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    print line
print lines, words #checking the count
# Out:
# []
# ['Project', 'Gutenberg', 'Etext', 'of', 'Romeo', 'and', 'Juliet', 'by', 'Shakespeare']
# ['PG', 'has', 'multiple', 'editions', 'of', 'William', "Shakespeare's", 'Complete', 'Works']
# []
# []
# ['Copyright', 'laws', 'are', 'changing', 'all', 'over', 'the', 'world,', 'be', 'sure', 'to', 'check']
# ['the', 'copyright', 'laws', 'for', 'your', 'country', 'before', 'posting', 'these', 'files!!']
# []
# ['Please', 'take', 'a', 'look', 'at', 'the', 'important', 'information', 'in', 'this', 'header.']
# ['We', 'encourage', 'you', 'to', 'keep', 'this', 'file', 'on', 'your', 'own', 'disk,', 'keeping', 'an']
# ['electronic', 'path', 'open', 'for', 'the', 'next', 'readers.', 'Do', 'not', 'remove', 'this.']
# []
# []
# ['**Welcome', 'To', 'The', 'World', 'of', 'Free', 'Plain', 'Vanilla', 'Electronic', 'Texts**']
# []
# 15 85

# %%
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in range(0,15): #taking a look at the first few split lines
    line=file.next().split()
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    print line
    for w in line: #getting characters
        w=w.strip('.,!*:()[]/')
        characters=characters+len(w)
        print w #checking the strip
print lines, words, characters #checking the count
# Out:
# []
# ['Project', 'Gutenberg', 'Etext', 'of', 'Romeo', 'and', 'Juliet', 'by', 'Shakespeare']
# Project
# Gutenberg
# Etext
# of
# Romeo
# and
# Juliet
# by
# Shakespeare
# ['PG', 'has', 'multiple', 'editions', 'of', 'William', "Shakespeare's", 'Complete', 'Works']
# PG
# has
# multiple
# editions
# of
# William
# Shakespeare's
# Complete
# Works
# []
# []
# ['Copyright', 'laws', 'are', 'changing', 'all', 'over', 'the', 'world,', 'be', 'sure', 'to', 'check']
# Copyright
# laws
# are
# changing
# all
# over
# the
# world
# be
# sure
# to
# check
# ['the', 'copyright', 'laws', 'for', 'your', 'country', 'before', 'posting', 'these', 'files!!']
# the
# copyright
# laws
# for
# your
# country
# before
# posting
# these
# files
# []
# ['Please', 'take', 'a', 'look', 'at', 'the', 'important', 'information', 'in', 'this', 'header.']
# Please
# take
# a
# look
# at
# the
# important
# information
# in
# this
# header
# ...

# %%
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in range(0,15): #taking a look at the first few split lines
    line=file.next().split()
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    print line
    for w in line: #getting characters
        w=w.strip('.,!*:()[]/')
        characters=characters+len(w)
        if w not in keys(Dict):
            Dict[w]=1
        else:
            Dict[w]=Dict[w]+1
print lines, words, characters #checking the count
# Out:
# []
# ['Project', 'Gutenberg', 'Etext', 'of', 'Romeo', 'and', 'Juliet', 'by', 'Shakespeare']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-47e646ff1fb8> in <module>()
#      13         w=w.strip('.,!*:()[]/')
#      14         characters=characters+len(w)
# ---> 15         if w not in keys(Dict):
#      16             Dict[w]=1
#      17         else:
#
# NameError: name 'keys' is not defined

# %%
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in range(0,15): #taking a look at the first few split lines
    line=file.next().split()
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    print line
    for w in line: #getting characters
        w=w.strip('.,!*:()[]/') #stripping punctuation
        characters=characters+len(w)
        if w not in Dict.keys(): #adding a word to the dictionary when it's not in keys, and incrementing otherwise
            Dict[w]=1
        else:
            Dict[w]=Dict[w]+1
print lines, words, characters #checking the count
print Dict
# Out:
# []
# ['Project', 'Gutenberg', 'Etext', 'of', 'Romeo', 'and', 'Juliet', 'by', 'Shakespeare']
# ['PG', 'has', 'multiple', 'editions', 'of', 'William', "Shakespeare's", 'Complete', 'Works']
# []
# []
# ['Copyright', 'laws', 'are', 'changing', 'all', 'over', 'the', 'world,', 'be', 'sure', 'to', 'check']
# ['the', 'copyright', 'laws', 'for', 'your', 'country', 'before', 'posting', 'these', 'files!!']
# []
# ['Please', 'take', 'a', 'look', 'at', 'the', 'important', 'information', 'in', 'this', 'header.']
# ['We', 'encourage', 'you', 'to', 'keep', 'this', 'file', 'on', 'your', 'own', 'disk,', 'keeping', 'an']
# ['electronic', 'path', 'open', 'for', 'the', 'next', 'readers.', 'Do', 'not', 'remove', 'this.']
# []
# []
# ['**Welcome', 'To', 'The', 'World', 'of', 'Free', 'Plain', 'Vanilla', 'Electronic', 'Texts**']
# []
# 15 85 413
# ...

# %%
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in file: #Going through all of the lines now
    line=i.split()
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    for w in line: #getting characters
        w=w.strip('.,!*:()[]/') #stripping punctuation
        characters=characters+len(w)
        if w not in Dict.keys(): #adding a word to the dictionary when it's not in keys, and incrementing otherwise
            Dict[w]=1
        else:
            Dict[w]=Dict[w]+1
print lines, words, characters #checking the count
for key in Dict.keys(): #displaying hte dictionary
    print key, Dict[key]
# Out:
# 5568 27463 118963
#  12
# yellow 1
# hanging 1
# Etexts 9
# conjure 4
# sound'?-- 1
# portentous 1
# foul 4
# stabbed 1
# bringing 1
# rancour 1
# Lest 2
# waverer 1
# disturb 2
# accidents; 1
# lady!-- 1
# hist!--O 1
# Murder'd 1
# pulse 1
# her; 4
# second 7
# &c 3
# her? 1
# valiant 2
# man:-- 1
# errors 1
# fingers 5
# madman's 1
# etexts 6
# serving-creature 1
# here 53
# talk'd 2
# hers 4
# shriek 1
# substance 3
# Mercutio's 5
# NOT 4
# golden 4
# Mantua; 2
# died,-- 1
# Three 4
# replace 1
# brought 1
# cherishing 1
# spoke 5
# music 5
# therefore 12
# strike 4
# holy 19
# brings 1
# hurt 4
# heap'd 1
# tying 1
# lord 21
# 90 1
# hole 1
# hold 7
# Jacks; 1
# mouse-hunt 1
# sweeten 1
# blade 1
# sweeter 1
# packthread 1
# NOTICE 1
# potion's 1
# deformities? 1
# Lo 1
# Trillion 2
# Revive 1
# disparagement 1
# want 4
# motion 2
# turn 7
# damage 1
# Killing 1
# machine 1
# how 33
# hot 5
# hop 1
# He'll 1
# dignified 1
# A 62
# beauty 9
# wrong 4
# Alack 6
# hay.-- 1
# ...

# %%
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in file: #Going through all of the lines now
    line=i.split()
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    for w in line: #getting characters
        w=w.strip(".,!*:()[]/?-';\"%~") #stripping some more punctuation
        characters=characters+len(w)
        if w not in Dict.keys(): #adding a word to the dictionary when it's not in keys, and incrementing otherwise
            Dict[w]=1
        else:
            Dict[w]=Dict[w]+1
print lines, words, characters #checking the count
for key in Dict.keys(): #displaying hte dictionary
    print key, Dict[key]
# Out:
# 5568 27463 117146
#  13
# you,--I 1
# gossamer 1
# Appear 1
# pardon 7
# ladybird 1
# Tempering 1
# needful 1
# felt 2
# fathom 1
# daughter's 3
# hath 53
# protest 3
# sleep 10
# hanging 1
# mansion 2
# appetite 1
# captain 1
# hate 12
# Etexts 9
# conjure 4
# whose 11
# doth 37
# clasps 1
# calculate 1
# rouse 3
# swan 1
# starv'd 1
# catch'd 1
# Afore 1
# under 5
# portentous 1
# sorry 1
# pride 2
# sway 1
# youngest 1
# wondrous 1
# merchant 1
# lure 1
# amorous 2
# O'er-cover'd 1
# hadst 5
# lurk 1
# mother?--why 1
# poor-John.--Draw 1
# Proud,--and 1
# disobedient 2
# every 10
# blisters 1
# distemper'd 1
# stabbed 1
# wash 1
# bringing 1
# courageous 1
# encounter 3
# pilgrim 2
# knowest 2
# four 1
# we'll 6
# MAY 1
# MONEY 1
# conceive 1
# sin-absolver 1
# of.--Tell 1
# hist!--O 1
# enforce 1
# Forbid 1
# xxxxx10x.xxx 1
# Murder'd 1
# Go 22
# murders 3
# one's 1
# Dost 3
# Our 5
# parted 1
# wild-goose 2
# eagle 1
# awake 2
# warns 1
# feathers 1
# request 4
# pulse 1
# ...

# %%
from re import *#Importing re for to use regex
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in file: #Going through all of the lines now
    line=findall("[\w]+", i) #using regex to deal with some annoying punctuation within "words"
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    for w in line: #getting characters
        w=w.strip(".,!*:()[]/?-';\"%~") #stripping some more punctuation
        characters=characters+len(w)
        if w not in Dict.keys(): #adding a word to the dictionary when it's not in keys, and incrementing otherwise
            Dict[w]=1
        else:
            Dict[w]=Dict[w]+1
print lines, words, characters #checking the count
for key in Dict.keys(): #displaying the dictionary
    print key, Dict[key]
# Out:
# 5568 27986 116107
#  24
# gossamer 1
# Appear 1
# pardon 9
# ladybird 1
# demand 1
# needful 1
# felt 2
# fathom 1
# daughter's 3
# hath 53
# protest 3
# sleep 10
# hanging 1
# mansion 2
# appetite 1
# captain 1
# hate 12
# Etexts 9
# conjure 4
# whose 11
# doth 37
# clasps 1
# calculate 1
# rouse 3
# swan 1
# starv'd 1
# boundless 1
# catch'd 1
# Afore 1
# under 5
# portentous 1
# sorry 1
# pride 2
# sway 1
# youngest 1
# wondrous 1
# merchant 1
# lure 1
# amorous 2
# hadst 5
# penny 1
# testify 1
# bird's 1
# disobedient 2
# every 11
# blisters 1
# distemper'd 1
# stabbed 1
# bringing 1
# courageous 1
# encounter 3
# pilgrim 2
# knowest 2
# four 1
# we'll 6
# MAY 1
# MONEY 1
# conceive 1
# dateless 1
# Leap 1
# enforce 1
# Forbid 1
# Murder'd 1
# Go 25
# murders 3
# one's 1
# Dost 3
# Our 5
# parted 1
# Draws 1
# awake 2
# warns 1
# feathers 1
# request 4
# pulse 1
# second 7
# street 2
# valiant 2
# Collins 1
# estimated 1
# machines 1
# shining 1
# even 11
# exil'd 1
# errors 1
# ...

# %%
from re import *#Importing re for to use regex
file=open('R_J.txt','r')
lines=0
words=0
characters=0
Dict={} #initializing the variables and the dictionary

for i in file: #Going through all of the lines now
    line=findall("[\w']+", i) #using regex to deal with some annoying punctuation within "words" and keeping apostrophes as part of the word
    lines=lines+1 #incrementing a couple counts
    words=words+len(line)
    for w in line: #getting characters
        w=w.strip(".,!*:()[]/?-';\"%~") #stripping some more punctuation
        characters=characters+len(w)
        if w not in Dict.keys(): #adding a word to the dictionary when it's not in keys, and incrementing otherwise
            Dict[w]=1
        else:
            Dict[w]=Dict[w]+1
print 'lines:', lines, 'words:', words, 'characters', characters #checking the count
large=['',0] #finding the word with the most mentions
for key in Dict.keys(): #displaying the dictionary
    print key, Dict[key]
    if Dict[key]>large[1]: #getting the word with the most mentions
        large[0]=key
        large[1]=Dict[key]

print(len(Dict.keys())) #printing the # of unique words
print large #printing the word with the most mentions
# Out:
# lines: 5568 words: 27986 characters 116107
#  24
# gossamer 1
# Appear 1
# pardon 9
# ladybird 1
# demand 1
# needful 1
# felt 2
# fathom 1
# daughter's 3
# hath 53
# protest 3
# sleep 10
# hanging 1
# mansion 2
# appetite 1
# captain 1
# hate 12
# Etexts 9
# conjure 4
# whose 11
# doth 37
# clasps 1
# calculate 1
# rouse 3
# swan 1
# starv'd 1
# boundless 1
# catch'd 1
# Afore 1
# under 5
# portentous 1
# sorry 1
# pride 2
# sway 1
# youngest 1
# wondrous 1
# merchant 1
# lure 1
# amorous 2
# hadst 5
# penny 1
# testify 1
# bird's 1
# disobedient 2
# every 11
# blisters 1
# distemper'd 1
# stabbed 1
# bringing 1
# courageous 1
# encounter 3
# pilgrim 2
# knowest 2
# four 1
# we'll 6
# MAY 1
# MONEY 1
# conceive 1
# dateless 1
# Leap 1
# enforce 1
# Forbid 1
# Murder'd 1
# Go 25
# murders 3
# one's 1
# Dost 3
# Our 5
# parted 1
# Draws 1
# awake 2
# warns 1
# feathers 1
# request 4
# pulse 1
# second 7
# street 2
# valiant 2
# Collins 1
# estimated 1
# machines 1
# shining 1
# ...

# %% [markdown]
# Write up:
# The only file I am handing in is exercise4; all documents are on this file.
#
# I found 5568 lines, 27986 words, and 116107 characters. The exact # of words and characters presumably will be different than that found by others because of how I divided words/eliminated punctuation.
#
# For the dictionary, there were 4718 unique words, with the most common word being the with
